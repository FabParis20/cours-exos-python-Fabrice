# %% [markdown]
# # Exercice à faire
#
# **Ennoncé :**
#
# Ecrire une fonction qui prend en entrée un str une valeur et:
# - Renvoie un int s'il s'agit d'une valeur convertible en int (ex: "132")
# - Renvoie un str sinon s'il s'agit d'un str non convertible en int (ex: "132, rue de Marseille")
# - Sinon None
#
# adapter_valeur("134") => 134
# adapter_valeur("12, rue de Paris") => "12, rue de Paris"
# adapter_valeur(142) => None
#
# En Python on peut tester si un element fait partie d'une liste en faisant "a" in "babar
#
# Essayer de coder 2 ou 3 façons différentes de faire

# %% [markdown]
# ## Résolution avec boucle for

# %%
def c_quoi(chaine):
    possible_nb = ""
    if type(chaine) != str:        
        return None        
    for carac in chaine:       
        if carac not in "123456789":
            return chaine        
    return int(chaine)
    
print(c_quoi("12, rue de paris"))
# Out:
# 12, rue de paris

# %%
print(c_quoi("123"))
# Out:
# 123

# %%
c_quoi("86 rue Puixérécourt")
# Out:
# '86 rue Puixérécourt'

# %% [markdown]
# Trouver a dans baba

# %%
def trouve_1(chaine):
    if "1" in chaine:
        print("OK")
    else:
        print("Non")

trouve_1("123")
# Out:
# OK
