# %%
# Variable locale - variable qui n'existe que dans une fonction
# exemple
def calculer_a():
    a = 10
    return a

# %% [markdown]
# Terminal = lancer des commandes, (ex : bash, etc...)
# Quand je tape python je suis dans l'interpréteur
# Dans l'interpréteur je ne peux pas appeler une seule fonction
